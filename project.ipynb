# %%
import os
import socket
from pyspark import SparkConf, SparkContext, SQLContext
from pyspark.sql import SparkSession
from pyspark.sql.window import Window
from pyspark.sql.types import BooleanType, IntegerType, LongType, StringType, ArrayType, FloatType, StructType, StructField
from pyspark.sql.functions import pandas_udf
from pyspark.sql.functions import PandasUDFType
from pyspark import StorageLevel
from jinja2 import Environment, FileSystemLoader

import pyspark.sql.functions as F
from pyspark.sql.functions import udf, length, when, col
from emoji import get_emoji_regexp, unicode_codes
import re

# %%
import numpy as np

# %%
# setting constants
APP_NAME = "YOUR_APP_NAME"
NORMALIZED_APP_NAME = APP_NAME.replace('/', '_').replace(':', '_')

APPS_TMP_DIR = os.path.join(os.getcwd(), "tmp")
APPS_CONF_DIR = os.path.join(os.getcwd(), "conf")
APPS_LOGS_DIR = os.path.join(os.getcwd(), "logs")
LOG4J_PROP_FILE = os.path.join(APPS_CONF_DIR, "pyspark-log4j-{}.properties".format(NORMALIZED_APP_NAME))
LOG_FILE = os.path.join(APPS_LOGS_DIR, 'pyspark-{}.log'.format(NORMALIZED_APP_NAME))
EXTRA_JAVA_OPTIONS = "-Dlog4j.configuration=file://{} -Dspark.hadoop.dfs.replication=1 -Dhttps.protocols=TLSv1.0,TLSv1.1,TLSv1.2,TLSv1.3"\
    .format(LOG4J_PROP_FILE)

LOCAL_IP = socket.gethostbyname(socket.gethostname())

# preparing configuration files from templates
for directory in [APPS_CONF_DIR, APPS_LOGS_DIR, APPS_TMP_DIR]:
    if not os.path.exists(directory):
        os.makedirs(directory)

env = Environment(loader=FileSystemLoader('/opt'))
template = env.get_template("pyspark_log4j.properties.template")
template\
    .stream(logfile=LOG_FILE)\
    .dump(LOG4J_PROP_FILE)

# run spark
spark = SparkSession\
    .builder\
    .appName(APP_NAME)\
    .master("k8s://https://10.32.7.103:6443")\
    .config("spark.driver.host", LOCAL_IP)\
    .config("spark.ui.port", "4040")\
    .config("spark.kubernetes.memoryOverheadFactor", "0.6")\
    .config("spark.driver.memory", "4g")\
    .config("spark.driver.bindAddress", "0.0.0.0")\
    .config("spark.executor.instances", "5")\
    .config("spark.executor.cores", '4')\
    .config("spark.executor.memory", "5g")\
    .config("spark.memory.fraction", "0.6")\
    .config("spark.memory.storageFraction", "0.5")\
    .config("spark.sql.autoBroadcastJoinThreshold", "-1")\
    .config("spark.driver.extraJavaOptions", EXTRA_JAVA_OPTIONS)\
    .config("spark.kubernetes.namespace", "gkulagin-307618")\
    .config("spark.kubernetes.driver.label.appname", APP_NAME)\
    .config("spark.kubernetes.executor.label.appname", APP_NAME)\
    .config("spark.kubernetes.container.image.pullPolicy", "Always")\
    .config("spark.kubernetes.container.image", "node03.st:5000/spark-executor:gkulagin-307618")\
    .config("spark.kubernetes.executor.deleteOnTermination", "true")\
    .config("spark.local.dir", "/tmp/spark")\
    .getOrCreate()

# %%
# spark.stop()

# %%
#read wikipedia texts
test_df = spark.read.text("hdfs:///shared/wiki_corpus_english", lineSep="---END.OF.DOCUMENT---\n")
   # .withColumn("pp_id", F.row_number().over(Window.orderBy("value"))).cache()

# %%
import nltk
nltk.data.path.append("/home/jovyan/nfs-home/nltk_data")

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
#functions for performing tokenozation and cleaning
from pyspark.ml.feature import RegexTokenizer
regexTokenizer = RegexTokenizer(inputCol="cleaned", outputCol="tokens", pattern=r"\s+")

import nltk
from nltk.corpus import stopwords
en_stopwords = stopwords.words("english")

@udf(returnType=ArrayType(StringType()))
def preprocess_udf(tokens):
    return [word for word in tokens if (word not in en_stopwords) and (len(word) > 3)]

def explode_words(base_df, text_col_name):
    return regexTokenizer.transform(
            base_df.withColumn("cleaned", F.regexp_replace(text_col_name, "([^a-zA-Z\s]|\n)+", " "))
        ).withColumn("words_array", preprocess_udf("tokens"))

# %%
words = explode_words(test_df, 'value').repartition(10)

# %%
words.show(2)
# Out:
# +--------------------+-------+--------------------+--------------------+--------------------+
# |               value|  pp_id|             cleaned|              tokens|         words_array|
# +--------------------+-------+--------------------+--------------------+--------------------+
# |
# Hong Kong films ...|1201283| Hong Kong films ...|[hong, kong, film...|[hong, kong, film...|
# |
# Juha Mieto.
# Juha...|1413176| Juha Mieto Juha ...|[juha, mieto, juh...|[juha, mieto, juh...|
# +--------------------+-------+--------------------+--------------------+--------------------+
# only showing top 2 rows

# %%
from pyspark.ml.feature import CountVectorizer

# %%
#Model for creating word matrix 
Vector = CountVectorizer(inputCol="words_array", outputCol="vectors", vocabSize=5000, minDF=10.0)
model = Vector.fit(words)

# %%
result = model.transform(words)

# %%
result.show()
# Out:
# +--------------------+-------+--------------------+--------------------+--------------------+--------------------+
# |               value|  pp_id|             cleaned|              tokens|         words_array|             vectors|
# +--------------------+-------+--------------------+--------------------+--------------------+--------------------+
# |
# Hong Kong films ...|1201283| Hong Kong films ...|[hong, kong, film...|[hong, kong, film...|(5000,[228,241,54...|
# |
# Juha Mieto.
# Juha...|1413176| Juha Mieto Juha ...|[juha, mieto, juh...|[juha, mieto, juh...|(5000,[0,8,25,31,...|
# |
# 16053 Brennan.
# 1...|  10615|  Brennan  Brenna...|[brennan, brennan...|[brennan, brennan...|(5000,[34,118,165...|
# |
# Nilsson Sings Ne...|1959996| Nilsson Sings Ne...|[nilsson, sings, ...|[nilsson, sings, ...|(5000,[10,22,38,4...|
# |
# Aleksandr Usov.
# ...| 163767| Aleksandr Usov A...|[aleksandr, usov,...|[aleksandr, usov,...|(5000,[2,8,10,25,...|
# |
# LCDR R class.
# Th...|1520217| LCDR R class The...|[lcdr, r, class, ...|[lcdr, class, lcd...|(5000,[3,7,16,20,...|
# |
# Esha Deol.
# Esha ...| 877375| Esha Deol Esha D...|[esha, deol, esha...|[esha, deol, esha...|(5000,[0,5,10,15,...|
# |
# Chilton Trinity ...| 564887| Chilton Trinity ...|[chilton, trinity...|[chilton, trinity...|(5000,[4,85,171,1...|
# |
# Hillary Profita....|1182810| Hillary Profita ...|[hillary, profita...|[hillary, profita...|(5000,[9,46,94,28...|
# |
# St. Cloud Region...|2529380| St  Cloud Region...|[st, cloud, regio...|[cloud, regional,...|(5000,[6,9,14,21,...|
# |
# College Football...| 615521| College Football...|[college, footbal...|[college, footbal...|(5000,[3,10,13,18...|
# |
# James Franklin H...|1313206| James Franklin H...|[james, franklin,...|[james, franklin,...|(5000,[0,1,3,4,5,...|
# |
# Alliance for a N...| 182127| Alliance for a N...|[alliance, for, a...|[alliance, humani...|(5000,[0,8,14,19,...|
# |
# Peter Miles (Ame...|2111998| Peter Miles  Ame...|[peter, miles, am...|[peter, miles, am...|(5000,[1,4,16,25,...|
# |
# The Siege of Lac...|2692651| The Siege of Lac...|[the, siege, of, ...|[siege, lachish, ...|(5000,[6,38,58,66...|
# |
# Giant (band).
# Gi...|1039614| Giant  band Gian...|[giant, band, gia...|[giant, band, gia...|(5000,[17,26,35,3...|
# |
# Pentecostal Coll...|2099562| Pentecostal Coll...|[pentecostal, col...|[pentecostal, col...|(5000,[0,1,2,3,4,...|
# |
# List of Russian ...|1610736| List of Russian ...|[list, of, russia...|[list, russian, r...|(5000,[241,293,60...|
# |
# The Virus (Siriu...|2700386| The Virus  Siriu...|[the, virus, siri...|[virus, sirius, v...|(5000,[0,2,3,5,7,...|
# |
# Pilchaca Distric...|2134632| Pilchaca Distric...|[pilchaca, distri...|[pilchaca, distri...|(5000,[63,425,168...|
# +--------------------+-------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.mllib.clustering import LDA, LDAModel
from pyspark.mllib.linalg import Vector, Vectors

# %%
corpus = result.select("pp_id", "vectors").rdd.map(lambda x: [x[0],Vectors.fromML(x[1])]).cache()

# %%
# performing LDA clustering
num_topics = 10
max_iterations = 100
ldaModel = LDA.train(corpus, k=num_topics,maxIterations=max_iterations)

# %%
topics = ldaModel.topicsMatrix()
vocabArray = model.vocabulary

# %%
wordNumbers = 10  # number of words per topic
topicIndices = SparkContext.getOrCreate().parallelize(ldaModel.describeTopics(maxTermsPerTopic = wordNumbers), 10)

# %%
def topic_render(topic):  # specify vector id of words to actual words
    terms = topic[0]
    values = topic[1]
    result = []
    for i in range(wordNumbers):
        term = vocabArray[terms[i]]
        value = values[i]
        result.append([term, value])
    return result

# %%
topics_final_2 = topicIndices.map(lambda topic: topic_render(topic)).collect()

# %%
#topics and top words for each topic
for topic in range(len(topics_final)):
    print ("Topic" + str(topic) + ":")
    for term in topics_final[topic]:
        print (term)
    print ('\n')
# Out:
# Topic0:
# born
# john
# church
# work
# first
# life
# became
# family
# later
# died
#
#
# Topic1:
# used
# system
# also
# time
# number
# formula
# using
# based
# design
# systems
#
#
# Topic2:
# government
# party
# political
# would
# people
# court
# election
# state
# union
# country
#
#
# Topic3:
# british
# army
# first
# force
# battle
# forces
# military
# august
# united
# september
#
#
# Topic4:
# city
# area
# south
# north
# county
# located
# town
# west
# district
# river
#
#
# Topic5:
# school
# university
# college
# state
# national
# high
# public
# company
# students
# also
#
#
# Topic6:
# also
# many
# used
# known
# found
# often
# species
# long
# name
# water
#
#
# Topic7:
# film
# series
# show
# also
# time
# would
# television
# story
# first
# character
#
#
# Topic8:
# first
# team
# season
# game
# played
# league
# club
# football
# career
# games
#
#
# Topic9:
# album
# music
# band
# released
# song
# years
# single
# also
# population
# american

# %%
topics_final_2
# Out:
# [[['born', 0.014906143038709973],
#   ['john', 0.013290677702466579],
#   ['church', 0.011054318910827431],
#   ['work', 0.010994565165982583],
#   ['first', 0.0103675867410336],
#   ['life', 0.010058503577044173],
#   ['became', 0.010047711777119151],
#   ['family', 0.009761875628137085],
#   ['later', 0.008955850745890118],
#   ['died', 0.008813185240909877]],
#  [['used', 0.011228794188256693],
#   ['system', 0.010217236054961786],
#   ['also', 0.0072296286060304525],
#   ['time', 0.005160303839175323],
#   ['number', 0.0049987006591577605],
#   ['formula', 0.004867458011006839],
#   ['using', 0.0048570965120763795],
#   ['based', 0.0046646660141394635],
#   ['design', 0.0042210956678548454],
#   ['systems', 0.004077324038620379]],
#  [['government', 0.012817274514444723],
#   ['party', 0.01108290696294041],
#   ['political', 0.007165457291397806],
#   ['would', 0.006401080253748718],
#   ['people', 0.006158141079973749],
#   ['court', 0.006156535999765254],
#   ['election', 0.006014939332135301],
#   ['state', 0.005848695782747611],
#   ['union', 0.005200455176285104],
#   ['country', 0.005124696493549132]],
#  [['british', 0.011300607536734201],
#   ['army', 0.010504153714662241],
#   ['first', 0.009095399575705477],
#   ['force', 0.008457696716211658],
#   ['battle', 0.007312930077129654],
#   ['forces', 0.006634637444501306],
#   ['military', 0.006614989278719913],
#   ['august', 0.006534599637623962],
#   ['united', 0.006321425670297502],
#   ['september', 0.005954574987961766]],
#  [['city', 0.022958903478249526],
#   ['area', 0.019332904672107333],
#   ['south', 0.017753799333657592],
#   ['north', 0.017581780066248772],
#   ['county', 0.015394642966704635],
#   ['located', 0.014291874283227745],
#   ['town', 0.013888822677511771],
#   ['west', 0.013802741929705894],
#   ['district', 0.013725281662824742],
#   ['river', 0.012504892139807376]],
#  [['school', 0.03148833068276343],
#   ['university', 0.022734025369751137],
#   ['college', 0.01261357060367887],
#   ['state', 0.011425921686679778],
#   ['national', 0.011394983849813294],
#   ['high', 0.010554298580633694],
#   ['public', 0.009839585326723856],
#   ['company', 0.00859236767139538],
#   ['students', 0.008387645427296546],
#   ['also', 0.007615697370829089]],
#  [['also', 0.014409252598067569],
#   ['many', 0.01164345889001625],
#   ['used', 0.011163113905933372],
#   ['known', 0.010451320472245146],
#   ['found', 0.009629215799131247],
#   ['often', 0.008637638858658791],
#   ['species', 0.008616906765809468],
#   ['long', 0.007416429196391751],
#   ['name', 0.007132138409255478],
#   ['water', 0.006872431833942043]],
#  [['film', 0.015382274781205766],
#   ['series', 0.012773769029961001],
#   ['show', 0.009658935531256827],
#   ['also', 0.008160899847229125],
#   ['time', 0.007626320351051961],
#   ['would', 0.007457495452297342],
#   ['television', 0.006627914878370314],
#   ['story', 0.006066283445563625],
#   ['first', 0.005630491860089955],
#   ['character', 0.005394592751978569]],
#  [['first', 0.022654221360195275],
#   ['team', 0.01948633847007925],
#   ['season', 0.017802485013584248],
#   ['game', 0.015550027319187795],
#   ['played', 0.013936858875323537],
#   ['league', 0.013602273731843022],
#   ['club', 0.01252502803491557],
#   ['football', 0.010878982748312324],
#   ['career', 0.00973091598069509],
#   ['games', 0.00952399952523202]],
#  [['album', 0.02313318695470735],
#   ['music', 0.02225312097966935],
#   ['band', 0.018291395664821165],
#   ['released', 0.0182490508976163],
#   ['song', 0.01432127481999905],
#   ['years', 0.011800358187657563],
#   ['single', 0.01072687021798397],
#   ['also', 0.010464244087883084],
#   ['population', 0.00948375404840781],
#   ['american', 0.009024163754119132]]]

# %%
topicIndices.collect()
# Out:
# [([25, 67, 103, 46, 1, 50, 24, 36, 11, 150],
#   [0.014906143038709973,
#    0.013290677702466579,
#    0.011054318910827431,
#    0.010994565165982583,
#    0.0103675867410336,
#    0.010058503577044173,
#    0.010047711777119151,
#    0.009761875628137085,
#    0.008955850745890118,
#    0.008813185240909877]),
#  ([9, 68, 0, 2, 47, 296, 200, 66, 339, 370],
#   [0.011228794188256693,
#    0.010217236054961786,
#    0.0072296286060304525,
#    0.005160303839175323,
#    0.0049987006591577605,
#    0.004867458011006839,
#    0.0048570965120763795,
#    0.0046646660141394635,
#    0.0042210956678548454,
#    0.004077324038620379]),
#  ([54, 92, 203, 5, 32, 209, 273, 15, 245, 140],
#   [0.012817274514444723,
#    0.01108290696294041,
#    0.007165457291397806,
#    0.006401080253748718,
#    0.006158141079973749,
#    0.006156535999765254,
#    0.006014939332135301,
#    0.005848695782747611,
#    0.005200455176285104,
#    0.005124696493549132]),
#  ([65, 137, 1, 186, 234, 263, 190, 114, 14, 112],
#   [0.011300607536734201,
#    0.010504153714662241,
#    0.009095399575705477,
#    0.008457696716211658,
#    0.007312930077129654,
#    0.006634637444501306,
#    0.006614989278719913,
#    0.006534599637623962,
#    0.006321425670297502,
#    0.005954574987961766]),
#  ([6, 28, 20, 27, 42, 60, 52, 51, 63, 78],
#   [0.022958903478249526,
#    0.019332904672107333,
#    0.017753799333657592,
#    0.017581780066248772,
#    0.015394642966704635,
#    0.014291874283227745,
#    0.013888822677511771,
#    0.013802741929705894,
#    0.013725281662824742,
#    0.012504892139807376]),
#  ([4, 18, 85, 15, 19, 30, 94, 53, 189, 0],
#   [0.03148833068276343,
#    0.022734025369751137,
#    0.01261357060367887,
#    0.011425921686679778,
#    0.011394983849813294,
#    0.010554298580633694,
#    0.009839585326723856,
#    0.00859236767139538,
#    0.008387645427296546,
#    0.007615697370829089]),
#  ([0, 7, 9, 12, 74, 102, 160, 69, 33, 145],
#   [0.014409252598067569,
#    0.01164345889001625,
#    0.011163113905933372,
#    0.010451320472245146,
#    0.009629215799131247,
#    0.008637638858658791,
#    0.008616906765809468,
#    0.007416429196391751,
#    0.007132138409255478,
#    0.006872431833942043]),
#  ([41, 43, 110, 0, 2, 5, 218, 248, 1, 310],
#   [0.015382274781205766,
#    0.012773769029961001,
#    0.009658935531256827,
#    0.008160899847229125,
#    0.007626320351051961,
#    0.007457495452297342,
#    0.006627914878370314,
#    0.006066283445563625,
#    0.005630491860089955,
#    0.005394592751978569]),
#  ([1, 34, 45, 59, 58, 76, 93, 129, 90, 161],
#   [0.022654221360195275,
#    0.01948633847007925,
#    0.017802485013584248,
#    0.015550027319187795,
#    0.013936858875323537,
#    0.013602273731843022,
#    0.01252502803491557,
#    0.010878982748312324,
#    0.00973091598069509,
#    0.00952399952523202]),
#  ([38, 44, 64, 55, 115, 3, 117, 0, 56, 26],
#   [0.02313318695470735,
#    0.02225312097966935,
#    0.018291395664821165,
#    0.0182490508976163,
#    0.01432127481999905,
#    0.011800358187657563,
#    0.01072687021798397,
#    0.010464244087883084,
#    0.00948375404840781,
#    0.009024163754119132])]

# %%
from pyspark.mllib.feature import Normalizer
labels = result.select('value')
features = result.select('vectors')

# %%
#calcualting word count for each paper
result.withColumn('words_count', F.size('tokens')).show(5)
# Out:
# +--------------------+-------+--------------------+--------------------+--------------------+--------------------+-----------+
# |               value|  pp_id|             cleaned|              tokens|         words_array|             vectors|words_count|
# +--------------------+-------+--------------------+--------------------+--------------------+--------------------+-----------+
# |
# Hong Kong films ...|1201283| Hong Kong films ...|[hong, kong, film...|[hong, kong, film...|(5000,[228,241,54...|         13|
# |
# Juha Mieto.
# Juha...|1413176| Juha Mieto Juha ...|[juha, mieto, juh...|[juha, mieto, juh...|(5000,[0,8,25,31,...|        169|
# |
# 16053 Brennan.
# 1...|  10615|  Brennan  Brenna...|[brennan, brennan...|[brennan, brennan...|(5000,[34,118,165...|         22|
# |
# Nilsson Sings Ne...|1959996| Nilsson Sings Ne...|[nilsson, sings, ...|[nilsson, sings, ...|(5000,[10,22,38,4...|         81|
# |
# Aleksandr Usov.
# ...| 163767| Aleksandr Usov A...|[aleksandr, usov,...|[aleksandr, usov,...|(5000,[2,8,10,25,...|         76|
# +--------------------+-------+--------------------+--------------------+--------------------+--------------------+-----------+
# only showing top 5 rows

# %%
df = result.select('value', col('vectors'))

# %%
@udf(returnType=FloatType())
def cos_sim_udf(a,b):
    return float(np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b)))

# %%
#calculationg top separated articles
new_df = df.crossJoin(df.select(col("vectors").alias('vectors_2')))\
    .withColumn("product", cos_sim_udf(col('vectors'), col('vectors_2')))\
    .where("product<1").groupBy(col("vectors")).agg(F.max("product").name('max_product'))\
    .orderBy('max_product')

# %%
new_df.show()

# %%
#end of project

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(result.select('words_count'))
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-58-5b37b5d37180> in <module>
# ----> 1 plt.hist(result.select('words_count'))
#
# /usr/local/spark/python/pyspark/sql/dataframe.py in select(self, *cols)
#    1667         [Row(name='Alice', age=12), Row(name='Bob', age=15)]
#    1668         """
# -> 1669         jdf = self._jdf.select(self._jcols(*cols))
#    1670         return DataFrame(jdf, self.sql_ctx)
#    1671
#
# /usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /usr/local/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# AnalysisException: cannot resolve '`words_count`' given input columns: [cleaned, pp_id, tokens, value, vectors, words_array];
# 'Project ['words_count]
# +- Project [value#0, pp_id#3, cleaned#111, tokens#118, words_array#127, UDF(words_array#127) AS vectors#241]
#    +- Repartition 10, true
#       +- Project [value#0, pp_id#3, cleaned#111, tokens#118, preprocess_udf(tokens#118) AS words_array#127]
#          +- Project [value#0, pp_id#3, cleaned#111, UDF(cleaned#111) AS tokens#118]
#             +- Project [value#0, pp_id#3, regexp_replace(value#0, ([^a-zA-Z\s]|
# )+,  , 1) AS cleaned#111]
#                +- Sample 0.0, 0.01, false, 5037635142968484735
#                   +- Project [value#0, pp_id#3]
#                      +- Project [value#0, pp_id#3, pp_id#3]
#                         +- Window [row_number() windowspecdefinition(value#0 ASC NULLS FIRST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS pp_id#3], [value#0 ASC NULLS FIRST]
#                            +- Project [value#0]
#                               +- Relation[value#0] text

# %%
normalizer = Normalizer()
data_2 = labels.zip(normalizer.transform(features))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-7387da816dab> in <module>
#       1 normalizer = Normalizer()
# ----> 2 data_2 = labels.zip(normalizer.transform(features))
#
# /usr/local/spark/python/pyspark/sql/dataframe.py in __getattr__(self, name)
#    1641         """
#    1642         if name not in self.columns:
# -> 1643             raise AttributeError(
#    1644                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1645         jc = self._jdf.apply(name)
#
# AttributeError: 'DataFrame' object has no attribute 'zip'

# %%
posts_df = spark.read.json("/shared/bigdata20/posts_api.json")

# %%
posts_likes_df = spark.read.parquet("/shared/bigdata20/posts_likes.parquet")
followers_df = spark.read.parquet("/shared/bigdata20/followers.parquet")
followers_posts_df = spark.read.json("/shared/bigdata20/followers_posts_api_final.json")
followers_posts_likes_df = spark.read.parquet("/shared/bigdata20/followers_posts_likes.parquet")

# %% [markdown]
# ## Task 1
# Find the top 20 posts in the group: (a) by likes; (b) by comments; (c) by reposts.

# %%
posts_df.printSchema()
# Out:
# root
#  |-- attachments: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- album: struct (nullable = true)
#  |    |    |    |-- created: long (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- size: long (nullable = true)
#  |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- updated: long (nullable = true)
#  |    |    |-- audio: struct (nullable = true)
#  |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |-- content_restricted: long (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |-- genre_id: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- is_hq: boolean (nullable = true)
#  |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- doc: struct (nullable = true)
#  |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- ext: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- preview: struct (nullable = true)
#  |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- video: struct (nullable = true)
#  |    |    |    |    |    |-- file_size: long (nullable = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |-- size: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- type: long (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- graffiti: struct (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- photo_200: string (nullable = true)
#  |    |    |    |-- photo_586: string (nullable = true)
#  |    |    |-- link: struct (nullable = true)
#  |    |    |    |-- button: struct (nullable = true)
#  |    |    |    |    |-- action: struct (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- button_action: string (nullable = true)
#  |    |    |    |-- button_text: string (nullable = true)
#  |    |    |    |-- caption: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |-- target: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- photo: struct (nullable = true)
#  |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |-- long: double (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- user_id: long (nullable = true)
#  |    |    |-- podcast: struct (nullable = true)
#  |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- podcast_info: struct (nullable = true)
#  |    |    |    |    |-- cover: struct (nullable = true)
#  |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- plays: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- poll: struct (nullable = true)
#  |    |    |    |-- anonymous: long (nullable = true)
#  |    |    |    |-- answer_id: long (nullable = true)
#  |    |    |    |-- answers: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- rate: double (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- votes: long (nullable = true)
#  |    |    |    |-- created: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- question: string (nullable = true)
#  |    |    |    |-- votes: long (nullable = true)
#  |    |    |-- posted_photo: struct (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- photo_130: string (nullable = true)
#  |    |    |    |-- photo_604: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- video: struct (nullable = true)
#  |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |-- can_add: long (nullable = true)
#  |    |    |    |-- comments: long (nullable = true)
#  |    |    |    |-- content_restricted: long (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |-- first_frame_1024: string (nullable = true)
#  |    |    |    |-- first_frame_1280: string (nullable = true)
#  |    |    |    |-- first_frame_130: string (nullable = true)
#  |    |    |    |-- first_frame_160: string (nullable = true)
#  |    |    |    |-- first_frame_320: string (nullable = true)
#  |    |    |    |-- first_frame_4096: string (nullable = true)
#  |    |    |    |-- first_frame_720: string (nullable = true)
#  |    |    |    |-- first_frame_800: string (nullable = true)
#  |    |    |    |-- height: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- is_private: long (nullable = true)
#  |    |    |    |-- local_views: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- photo_1280: string (nullable = true)
#  |    |    |    |-- photo_130: string (nullable = true)
#  |    |    |    |-- photo_320: string (nullable = true)
#  |    |    |    |-- photo_640: string (nullable = true)
#  |    |    |    |-- photo_800: string (nullable = true)
#  |    |    |    |-- platform: string (nullable = true)
#  |    |    |    |-- repeat: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- track_code: string (nullable = true)
#  |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |-- views: long (nullable = true)
#  |    |    |    |-- width: long (nullable = true)
#  |-- comments: struct (nullable = true)
#  |    |-- can_post: long (nullable = true)
#  |    |-- count: long (nullable = true)
#  |    |-- groups_can_post: boolean (nullable = true)
#  |-- copy_history: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- attachments: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- album: struct (nullable = true)
#  |    |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- updated: long (nullable = true)
#  |    |    |    |    |-- audio: struct (nullable = true)
#  |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |    |    |-- content_restricted: long (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |    |    |-- genre_id: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- is_hq: boolean (nullable = true)
#  |    |    |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- doc: struct (nullable = true)
#  |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- ext: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- preview: struct (nullable = true)
#  |    |    |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- video: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- file_size: long (nullable = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- type: long (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- link: struct (nullable = true)
#  |    |    |    |    |    |-- button: struct (nullable = true)
#  |    |    |    |    |    |    |-- action: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- button_action: string (nullable = true)
#  |    |    |    |    |    |-- button_text: string (nullable = true)
#  |    |    |    |    |    |-- caption: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |    |-- target: string (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- page: struct (nullable = true)
#  |    |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |    |-- edited: long (nullable = true)
#  |    |    |    |    |    |-- group_id: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- parent2: string (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- view_url: string (nullable = true)
#  |    |    |    |    |    |-- views: long (nullable = true)
#  |    |    |    |    |    |-- who_can_edit: long (nullable = true)
#  |    |    |    |    |    |-- who_can_view: long (nullable = true)
#  |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |    |-- long: double (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |-- podcast: struct (nullable = true)
#  |    |    |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- podcast_info: struct (nullable = true)
#  |    |    |    |    |    |    |-- cover: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |-- plays: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- poll: struct (nullable = true)
#  |    |    |    |    |    |-- anonymous: long (nullable = true)
#  |    |    |    |    |    |-- answer_id: long (nullable = true)
#  |    |    |    |    |    |-- answers: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |-- rate: double (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |    |-- votes: long (nullable = true)
#  |    |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- question: string (nullable = true)
#  |    |    |    |    |    |-- votes: long (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- video: struct (nullable = true)
#  |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |-- can_add: long (nullable = true)
#  |    |    |    |    |    |-- comments: long (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |    |    |-- first_frame_1024: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_1280: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_130: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_160: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_320: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_4096: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_720: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_800: string (nullable = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- local_views: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- photo_1280: string (nullable = true)
#  |    |    |    |    |    |-- photo_130: string (nullable = true)
#  |    |    |    |    |    |-- photo_320: string (nullable = true)
#  |    |    |    |    |    |-- photo_640: string (nullable = true)
#  |    |    |    |    |    |-- photo_800: string (nullable = true)
#  |    |    |    |    |    |-- platform: string (nullable = true)
#  |    |    |    |    |    |-- repeat: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- track_code: string (nullable = true)
#  |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |    |-- views: long (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |-- date: long (nullable = true)
#  |    |    |-- from_id: long (nullable = true)
#  |    |    |-- geo: struct (nullable = true)
#  |    |    |    |-- coordinates: string (nullable = true)
#  |    |    |    |-- place: struct (nullable = true)
#  |    |    |    |    |-- city: string (nullable = true)
#  |    |    |    |    |-- country: string (nullable = true)
#  |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |-- icon: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- latitude: double (nullable = true)
#  |    |    |    |    |-- longitude: double (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- showmap: long (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- owner_id: long (nullable = true)
#  |    |    |-- post_source: struct (nullable = true)
#  |    |    |    |-- data: string (nullable = true)
#  |    |    |    |-- platform: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- post_type: string (nullable = true)
#  |    |    |-- signer_id: long (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- copyright: struct (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- link: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- date: long (nullable = true)
#  |-- from_id: long (nullable = true)
#  |-- geo: struct (nullable = true)
#  |    |-- coordinates: string (nullable = true)
#  |    |-- place: struct (nullable = true)
#  |    |    |-- city: string (nullable = true)
#  |    |    |-- country: string (nullable = true)
#  |    |    |-- created: long (nullable = true)
#  |    |    |-- icon: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- latitude: double (nullable = true)
#  |    |    |-- longitude: double (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |-- showmap: long (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- key: string (nullable = true)
#  |-- likes: struct (nullable = true)
#  |    |-- can_like: long (nullable = true)
#  |    |-- can_publish: long (nullable = true)
#  |    |-- count: long (nullable = true)
#  |    |-- user_likes: long (nullable = true)
#  |-- marked_as_ads: long (nullable = true)
#  |-- owner_id: long (nullable = true)
#  |-- post_source: struct (nullable = true)
#  |    |-- data: string (nullable = true)
#  |    |-- platform: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- post_type: string (nullable = true)
#  |-- reposts: struct (nullable = true)
#  |    |-- count: long (nullable = true)
#  |    |-- user_reposted: long (nullable = true)
#  |-- signer_id: long (nullable = true)
#  |-- text: string (nullable = true)
#  |-- unavailable: string (nullable = true)
#  |-- views: struct (nullable = true)
#  |    |-- count: long (nullable = true)

# %%
#(a) by likes
posts_df.select('id', col('likes.count').name('likes count'))\
        .orderBy("likes.count", ascending=False)\
        .show(20)
# Out:
# +-----+-----------+
# |   id|likes count|
# +-----+-----------+
# |32022|       1637|
# |35068|       1629|
# |17492|       1516|
# |18526|       1026|
# |19552|        955|
# |41468|        952|
# |19419|        868|
# |29046|        824|
# |32546|        786|
# |24085|        765|
# |40180|        759|
# |33658|        708|
# |13532|        633|
# |40842|        631|
# |35117|        588|
# |17014|        581|
# |19583|        553|
# |19809|        552|
# |27455|        550|
# |11999|        549|
# +-----+-----------+
# only showing top 20 rows

# %%
#(b) by comments
posts_df.select('id', col('comments.count').name('comments count'))\
        .orderBy("comments.count", ascending=False)\
        .show(20)
# Out:
# +-----+--------------+
# |   id|comments count|
# +-----+--------------+
# |24085|           850|
# |22540|           250|
# |27722|           192|
# | 8285|           148|
# |26860|           113|
# |13571|           107|
# |39294|           104|
# |36680|            96|
# |41739|            92|
# |26006|            92|
# |12426|            91|
# |21499|            88|
# |39163|            83|
# |39407|            83|
# |11267|            81|
# |31548|            80|
# |11158|            70|
# |39082|            67|
# |14602|            61|
# |12687|            61|
# +-----+--------------+
# only showing top 20 rows

# %%
#(c) by reposts
posts_df.select('id', col('reposts.count').name('reposts count'))\
        .orderBy("reposts.count", ascending=False)\
        .show(20)
# Out:
# +-----+-------------+
# |   id|reposts count|
# +-----+-------------+
# |17492|          334|
# |19552|          246|
# |32022|          210|
# |11842|          129|
# |19419|          126|
# |13532|          110|
# |17014|          105|
# |35068|          101|
# |41266|           92|
# |12593|           90|
# |29046|           87|
# |11999|           85|
# |41468|           85|
# |19809|           84|
# |17167|           81|
# |10833|           78|
# |18543|           77|
# |16596|           76|
# |18156|           74|
# |37262|           71|
# +-----+-------------+
# only showing top 20 rows

# %% [markdown]
# ## Task 2
# Find the top 20 users by (a) likes and (b) reposts they have made (to trace reposts use "copy_history" field)

# %%
posts_likes_df.printSchema()
# Out:
# root
#  |-- itemType: string (nullable = true)
#  |-- ownerId: integer (nullable = true)
#  |-- itemId: integer (nullable = true)
#  |-- likerId: integer (nullable = true)

# %%
#top 20 users by likes they have made
posts_likes_df.groupby('likerId')\
              .agg(F.count('itemId').name('likes_count'))\
              .orderBy('likes_count', ascending=False)\
              .select(col('likerId').name('user_id'), 'likes_count')\
              .show(20)
# Out:
# +---------+-----------+
# |  user_id|likes_count|
# +---------+-----------+
# |  2070090|       4801|
# |  2397858|       2055|
# |  1475301|       1829|
# |    18239|       1569|
# |   546612|       1245|
# |     6371|        907|
# |  1841959|        746|
# | 78440957|        709|
# |   120248|        699|
# | 40981497|        611|
# |    22158|        553|
# |207628162|        548|
# |329377723|        504|
# | 76071304|        474|
# | 14805173|        440|
# |   317799|        385|
# | 56355640|        375|
# | 52042971|        338|
# |  7437271|        336|
# |136506644|        335|
# +---------+-----------+
# only showing top 20 rows

# %%
followers_posts_df.printSchema()
# Out:
# root
#  |-- attachments: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- album: struct (nullable = true)
#  |    |    |    |-- created: long (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- size: long (nullable = true)
#  |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |-- long: double (nullable = true)
#  |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- updated: long (nullable = true)
#  |    |    |-- audio: struct (nullable = true)
#  |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |-- content_restricted: long (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |-- genre_id: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- is_hq: boolean (nullable = true)
#  |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- doc: struct (nullable = true)
#  |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- ext: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- preview: struct (nullable = true)
#  |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- video: struct (nullable = true)
#  |    |    |    |    |    |-- file_size: long (nullable = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |-- size: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- type: long (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- link: struct (nullable = true)
#  |    |    |    |-- button: struct (nullable = true)
#  |    |    |    |    |-- action: struct (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- button_action: string (nullable = true)
#  |    |    |    |-- button_text: string (nullable = true)
#  |    |    |    |-- caption: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |-- long: double (nullable = true)
#  |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- src_big: string (nullable = true)
#  |    |    |    |    |-- src_small: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |-- target: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- market: struct (nullable = true)
#  |    |    |    |-- availability: long (nullable = true)
#  |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- section: struct (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- price: struct (nullable = true)
#  |    |    |    |    |-- amount: string (nullable = true)
#  |    |    |    |    |-- currency: struct (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- thumb_photo: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |-- page: struct (nullable = true)
#  |    |    |    |-- created: long (nullable = true)
#  |    |    |    |-- creator_id: long (nullable = true)
#  |    |    |    |-- current_user_can_edit: long (nullable = true)
#  |    |    |    |-- current_user_can_edit_access: long (nullable = true)
#  |    |    |    |-- edited: long (nullable = true)
#  |    |    |    |-- editor_id: long (nullable = true)
#  |    |    |    |-- group_id: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- view_url: string (nullable = true)
#  |    |    |    |-- views: long (nullable = true)
#  |    |    |    |-- who_can_edit: long (nullable = true)
#  |    |    |    |-- who_can_view: long (nullable = true)
#  |    |    |-- photo: struct (nullable = true)
#  |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |-- long: double (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- user_id: long (nullable = true)
#  |    |    |-- photos_list: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- podcast: struct (nullable = true)
#  |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- is_hq: boolean (nullable = true)
#  |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- podcast_info: struct (nullable = true)
#  |    |    |    |    |-- cover: struct (nullable = true)
#  |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- plays: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- poll: struct (nullable = true)
#  |    |    |    |-- anonymous: long (nullable = true)
#  |    |    |    |-- answer_id: long (nullable = true)
#  |    |    |    |-- answers: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- rate: double (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- votes: long (nullable = true)
#  |    |    |    |-- created: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- question: string (nullable = true)
#  |    |    |    |-- votes: long (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- video: struct (nullable = true)
#  |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |-- can_add: long (nullable = true)
#  |    |    |    |-- comments: long (nullable = true)
#  |    |    |    |-- content_restricted: long (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |-- first_frame_1024: string (nullable = true)
#  |    |    |    |-- first_frame_1280: string (nullable = true)
#  |    |    |    |-- first_frame_130: string (nullable = true)
#  |    |    |    |-- first_frame_160: string (nullable = true)
#  |    |    |    |-- first_frame_320: string (nullable = true)
#  |    |    |    |-- first_frame_4096: string (nullable = true)
#  |    |    |    |-- first_frame_720: string (nullable = true)
#  |    |    |    |-- first_frame_800: string (nullable = true)
#  |    |    |    |-- height: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- is_private: long (nullable = true)
#  |    |    |    |-- live: long (nullable = true)
#  |    |    |    |-- local_views: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- photo_1280: string (nullable = true)
#  |    |    |    |-- photo_130: string (nullable = true)
#  |    |    |    |-- photo_320: string (nullable = true)
#  |    |    |    |-- photo_640: string (nullable = true)
#  |    |    |    |-- photo_800: string (nullable = true)
#  |    |    |    |-- platform: string (nullable = true)
#  |    |    |    |-- processing: long (nullable = true)
#  |    |    |    |-- repeat: long (nullable = true)
#  |    |    |    |-- spectators: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- track_code: string (nullable = true)
#  |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |-- views: long (nullable = true)
#  |    |    |    |-- width: long (nullable = true)
#  |-- comments: struct (nullable = true)
#  |    |-- can_post: long (nullable = true)
#  |    |-- count: long (nullable = true)
#  |    |-- groups_can_post: boolean (nullable = true)
#  |-- copy_history: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- attachments: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- album: struct (nullable = true)
#  |    |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |    |    |-- long: double (nullable = true)
#  |    |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- updated: long (nullable = true)
#  |    |    |    |    |-- audio: struct (nullable = true)
#  |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |    |    |-- content_restricted: long (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |    |    |-- genre_id: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- is_hq: boolean (nullable = true)
#  |    |    |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- doc: struct (nullable = true)
#  |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- ext: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- preview: struct (nullable = true)
#  |    |    |    |    |    |    |-- graffiti: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- video: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- file_size: long (nullable = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- type: long (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- link: struct (nullable = true)
#  |    |    |    |    |    |-- button: struct (nullable = true)
#  |    |    |    |    |    |    |-- action: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- group_id: long (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- button_action: string (nullable = true)
#  |    |    |    |    |    |-- button_text: string (nullable = true)
#  |    |    |    |    |    |-- caption: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |    |    |-- long: double (nullable = true)
#  |    |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |    |-- product: struct (nullable = true)
#  |    |    |    |    |    |    |-- price: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- amount: string (nullable = true)
#  |    |    |    |    |    |    |    |-- currency: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- target: string (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- video: struct (nullable = true)
#  |    |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |    |-- can_add: long (nullable = true)
#  |    |    |    |    |    |    |-- comments: long (nullable = true)
#  |    |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_1024: string (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_1280: string (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_130: string (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_160: string (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_320: string (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_4096: string (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_720: string (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_800: string (nullable = true)
#  |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |    |-- photo_1280: string (nullable = true)
#  |    |    |    |    |    |    |-- photo_130: string (nullable = true)
#  |    |    |    |    |    |    |-- photo_320: string (nullable = true)
#  |    |    |    |    |    |    |-- photo_800: string (nullable = true)
#  |    |    |    |    |    |    |-- processing: long (nullable = true)
#  |    |    |    |    |    |    |-- repeat: long (nullable = true)
#  |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |-- track_code: string (nullable = true)
#  |    |    |    |    |    |    |-- views: long (nullable = true)
#  |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- market: struct (nullable = true)
#  |    |    |    |    |    |-- availability: long (nullable = true)
#  |    |    |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |-- section: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- price: struct (nullable = true)
#  |    |    |    |    |    |    |-- amount: string (nullable = true)
#  |    |    |    |    |    |    |-- currency: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- thumb_photo: string (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- market_album: struct (nullable = true)
#  |    |    |    |    |    |-- count: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- updated_time: long (nullable = true)
#  |    |    |    |    |-- note: struct (nullable = true)
#  |    |    |    |    |    |-- comments: long (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- read_comments: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- view_url: string (nullable = true)
#  |    |    |    |    |-- page: struct (nullable = true)
#  |    |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |    |-- creator_id: long (nullable = true)
#  |    |    |    |    |    |-- current_user_can_edit: long (nullable = true)
#  |    |    |    |    |    |-- current_user_can_edit_access: long (nullable = true)
#  |    |    |    |    |    |-- edited: long (nullable = true)
#  |    |    |    |    |    |-- editor_id: long (nullable = true)
#  |    |    |    |    |    |-- group_id: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- parent: string (nullable = true)
#  |    |    |    |    |    |-- parent2: string (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- view_url: string (nullable = true)
#  |    |    |    |    |    |-- views: long (nullable = true)
#  |    |    |    |    |    |-- who_can_edit: long (nullable = true)
#  |    |    |    |    |    |-- who_can_view: long (nullable = true)
#  |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |    |-- long: double (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |-- photos_list: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- podcast: struct (nullable = true)
#  |    |    |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- is_explicit: boolean (nullable = true)
#  |    |    |    |    |    |-- is_hq: boolean (nullable = true)
#  |    |    |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- podcast_info: struct (nullable = true)
#  |    |    |    |    |    |    |-- cover: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |-- plays: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- poll: struct (nullable = true)
#  |    |    |    |    |    |-- anonymous: long (nullable = true)
#  |    |    |    |    |    |-- answer_id: long (nullable = true)
#  |    |    |    |    |    |-- answers: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |-- rate: double (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |    |-- votes: long (nullable = true)
#  |    |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- question: string (nullable = true)
#  |    |    |    |    |    |-- votes: long (nullable = true)
#  |    |    |    |    |-- pretty_cards: struct (nullable = true)
#  |    |    |    |    |    |-- cards: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- button: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- action: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- group_id: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- target: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |    |-- card_id: string (nullable = true)
#  |    |    |    |    |    |    |    |-- images: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |    |-- link_url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- link_url_target: string (nullable = true)
#  |    |    |    |    |    |    |    |-- photo: string (nullable = true)
#  |    |    |    |    |    |    |    |-- price: string (nullable = true)
#  |    |    |    |    |    |    |    |-- price_old: string (nullable = true)
#  |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- sticker: struct (nullable = true)
#  |    |    |    |    |    |-- images: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |-- images_with_background: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |-- product_id: long (nullable = true)
#  |    |    |    |    |    |-- sticker_id: long (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- video: struct (nullable = true)
#  |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |-- can_add: long (nullable = true)
#  |    |    |    |    |    |-- comments: long (nullable = true)
#  |    |    |    |    |    |-- content_restricted: long (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |    |    |-- first_frame_1024: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_1280: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_130: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_160: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_320: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_4096: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_720: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_800: string (nullable = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- is_private: long (nullable = true)
#  |    |    |    |    |    |-- live: long (nullable = true)
#  |    |    |    |    |    |-- local_views: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- photo_1280: string (nullable = true)
#  |    |    |    |    |    |-- photo_130: string (nullable = true)
#  |    |    |    |    |    |-- photo_320: string (nullable = true)
#  |    |    |    |    |    |-- photo_640: string (nullable = true)
#  |    |    |    |    |    |-- photo_800: string (nullable = true)
#  |    |    |    |    |    |-- platform: string (nullable = true)
#  |    |    |    |    |    |-- processing: long (nullable = true)
#  |    |    |    |    |    |-- repeat: long (nullable = true)
#  |    |    |    |    |    |-- spectators: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- track_code: string (nullable = true)
#  |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |    |-- views: long (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |-- date: long (nullable = true)
#  |    |    |-- final_post: long (nullable = true)
#  |    |    |-- from_id: long (nullable = true)
#  |    |    |-- geo: struct (nullable = true)
#  |    |    |    |-- coordinates: string (nullable = true)
#  |    |    |    |-- place: struct (nullable = true)
#  |    |    |    |    |-- address: string (nullable = true)
#  |    |    |    |    |-- checkins: long (nullable = true)
#  |    |    |    |    |-- city: string (nullable = true)
#  |    |    |    |    |-- country: string (nullable = true)
#  |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |-- icon: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- latitude: double (nullable = true)
#  |    |    |    |    |-- longitude: double (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- type: long (nullable = true)
#  |    |    |    |-- showmap: long (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- owner_id: long (nullable = true)
#  |    |    |-- post_source: struct (nullable = true)
#  |    |    |    |-- data: string (nullable = true)
#  |    |    |    |-- link: struct (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- platform: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- post_type: string (nullable = true)
#  |    |    |-- reply_post_id: long (nullable = true)
#  |    |    |-- signer_id: long (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- copyright: struct (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- link: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- date: long (nullable = true)
#  |-- final_post: long (nullable = true)
#  |-- from_id: long (nullable = true)
#  |-- geo: struct (nullable = true)
#  |    |-- coordinates: string (nullable = true)
#  |    |-- place: struct (nullable = true)
#  |    |    |-- address: string (nullable = true)
#  |    |    |-- checkins: long (nullable = true)
#  |    |    |-- city: string (nullable = true)
#  |    |    |-- country: string (nullable = true)
#  |    |    |-- created: long (nullable = true)
#  |    |    |-- icon: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- latitude: double (nullable = true)
#  |    |    |-- longitude: double (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- type: long (nullable = true)
#  |    |-- showmap: long (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- is_pinned: long (nullable = true)
#  |-- key: string (nullable = true)
#  |-- likes: struct (nullable = true)
#  |    |-- can_like: long (nullable = true)
#  |    |-- can_publish: long (nullable = true)
#  |    |-- count: long (nullable = true)
#  |    |-- user_likes: long (nullable = true)
#  |-- owner_id: long (nullable = true)
#  |-- post_source: struct (nullable = true)
#  |    |-- data: string (nullable = true)
#  |    |-- link: struct (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- platform: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- post_type: string (nullable = true)
#  |-- reposts: struct (nullable = true)
#  |    |-- count: long (nullable = true)
#  |    |-- user_reposted: long (nullable = true)
#  |-- signer_id: long (nullable = true)
#  |-- text: string (nullable = true)
#  |-- unavailable: string (nullable = true)
#  |-- views: struct (nullable = true)
#  |    |-- count: long (nullable = true)

# %%
#top 20 users by reposts they have made
followers_posts_df.select('owner_id', col("copy_history.id").getItem(0).name('post_id'))\
        .na.drop()\
        .groupby('owner_id')\
        .agg(F.count('post_id').name('posts_num'))\
        .orderBy('posts_num', ascending=False)\
        .show()
# Out:
# +---------+---------+
# | owner_id|posts_num|
# +---------+---------+
# |  2547211|    37742|
# |357231922|    23349|
# |168543860|    18429|
# | 25646344|    11122|
# |176861294|     9022|
# |524656784|     7242|
# |    29840|     7164|
# |143207077|     7161|
# |141687240|     6804|
# |459339006|     6741|
# |514384760|     6570|
# |483715951|     6052|
# |445159771|     5808|
# |451211328|     5646|
# |426396104|     5533|
# |  8325325|     5532|
# |452280411|     5458|
# |464220898|     5318|
# |440454268|     5304|
# |461319529|     5240|
# +---------+---------+
# only showing top 20 rows

# %% [markdown]
# ## Task 3
# get reposts of the original posts of the itmo group (posts.json) from user posts (the result should be similar to (group_post_id, Array (user_post_ids)))

# %%
followers_posts_df.select(
                        col('id').name('user_post_id'),
                        col("copy_history.id").getItem(0).name("post_id"),
                        col("copy_history.owner_id").getItem(0).name("owner_id")
                        )\
                  .join(
                        posts_df.select(col('id').name('post_id'), "owner_id"),
                        ['owner_id', 'post_id']
                        )\
                  .groupBy('post_id')\
                  .agg(F.collect_list('user_post_id').name('user_post_ids'))\
                  .withColumn('reposts_num', F.size('user_post_ids'))\
                  .orderBy('reposts_num', ascending=False)\
                  .show()
# Out:
# +-------+--------------------+-----------+
# |post_id|       user_post_ids|reposts_num|
# +-------+--------------------+-----------+
# |  41266|[1265, 1748, 88, ...|         30|
# |  41468|[1758, 1202, 390,...|         25|
# |  42482|[1190, 264, 2033,...|         10|
# |  40090|[349, 1760, 1325,...|          9|
# |  39259|[1205, 10810, 106...|          8|
# |  38740|[31900, 9561, 113...|          8|
# |  41721|[274, 8, 10896, 4...|          6|
# |  41207|[958, 2960, 4812,...|          6|
# |  41546|[1161, 666, 3908,...|          6|
# |  38963|[4868, 6403, 3720...|          5|
# |  41506|[397, 398, 670, 1...|          5|
# |  39682|[3368, 159, 600, ...|          5|
# |  41708|[271, 10107, 5112...|          4|
# |  42730|[7129, 4201, 5561...|          4|
# |  39294|[2319, 4718, 4516...|          4|
# |  38915|[18054, 4487, 470...|          4|
# |  39686|[3370, 4741, 305,...|          4|
# |  39515|[9218, 443, 7390,...|          4|
# |  41108|[10559, 182, 366,...|          4|
# |  41424|   [4125, 6941, 529]|          3|
# +-------+--------------------+-----------+
# only showing top 20 rows

# %% [markdown]
# ## Task 4
# find emoticons in posts (negative, positive, neutral), calculate their overall count,  frequency (number of posts they can be found in) and average count per post. Print top 10 most popular emoticons, print top 5 emoticons which have the greatest difference between their overall count and frequency, print top 5 emoticons with average count per post.

# %%
# !pip install --user --trusted-host pypi-registry.supplementary-services.svc.cluster.local --index http://pypi-registry.supplementary-services.svc.cluster.local:8080/ emoji
# Out:
# Looking in indexes: http://pypi-registry.supplementary-services.svc.cluster.local:8080/
# Requirement already satisfied: emoji in /opt/conda/lib/python3.8/site-packages (1.2.0)

# %%
import sys
# !{sys.executable} -m pip install --user --trusted-host pypi-registry.supplementary-services.svc.cluster.local --index http://pypi-registry.supplementary-services.svc.cluster.local:8080/ emoji
# Out:
# Looking in indexes: http://pypi-registry.supplementary-services.svc.cluster.local:8080/
# Requirement already satisfied: emoji in /opt/conda/lib/python3.8/site-packages (1.2.0)

# %%
from emoji import get_emoji_regexp, unicode_codes

# %%
@udf(returnType=ArrayType(StringType()))
def get_emoji_udf(text):
    all_matches = get_emoji_regexp().finditer(text)
    emoji = []
    for match in all_matches:
        emoji.append(match.group())
    
    return emoji

# %%
posts_df.printSchema()
# Out:
# root
#  |-- attachments: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- album: struct (nullable = true)
#  |    |    |    |-- created: long (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- size: long (nullable = true)
#  |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- updated: long (nullable = true)
#  |    |    |-- audio: struct (nullable = true)
#  |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |-- content_restricted: long (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |-- genre_id: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- is_hq: boolean (nullable = true)
#  |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- doc: struct (nullable = true)
#  |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- ext: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- preview: struct (nullable = true)
#  |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- video: struct (nullable = true)
#  |    |    |    |    |    |-- file_size: long (nullable = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |-- size: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- type: long (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- graffiti: struct (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- photo_200: string (nullable = true)
#  |    |    |    |-- photo_586: string (nullable = true)
#  |    |    |-- link: struct (nullable = true)
#  |    |    |    |-- button: struct (nullable = true)
#  |    |    |    |    |-- action: struct (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- button_action: string (nullable = true)
#  |    |    |    |-- button_text: string (nullable = true)
#  |    |    |    |-- caption: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |-- target: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- photo: struct (nullable = true)
#  |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |-- long: double (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- user_id: long (nullable = true)
#  |    |    |-- podcast: struct (nullable = true)
#  |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- podcast_info: struct (nullable = true)
#  |    |    |    |    |-- cover: struct (nullable = true)
#  |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- plays: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- poll: struct (nullable = true)
#  |    |    |    |-- anonymous: long (nullable = true)
#  |    |    |    |-- answer_id: long (nullable = true)
#  |    |    |    |-- answers: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- rate: double (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- votes: long (nullable = true)
#  |    |    |    |-- created: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- question: string (nullable = true)
#  |    |    |    |-- votes: long (nullable = true)
#  |    |    |-- posted_photo: struct (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- photo_130: string (nullable = true)
#  |    |    |    |-- photo_604: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- video: struct (nullable = true)
#  |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |-- can_add: long (nullable = true)
#  |    |    |    |-- comments: long (nullable = true)
#  |    |    |    |-- content_restricted: long (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |-- first_frame_1024: string (nullable = true)
#  |    |    |    |-- first_frame_1280: string (nullable = true)
#  |    |    |    |-- first_frame_130: string (nullable = true)
#  |    |    |    |-- first_frame_160: string (nullable = true)
#  |    |    |    |-- first_frame_320: string (nullable = true)
#  |    |    |    |-- first_frame_4096: string (nullable = true)
#  |    |    |    |-- first_frame_720: string (nullable = true)
#  |    |    |    |-- first_frame_800: string (nullable = true)
#  |    |    |    |-- height: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- is_private: long (nullable = true)
#  |    |    |    |-- local_views: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- photo_1280: string (nullable = true)
#  |    |    |    |-- photo_130: string (nullable = true)
#  |    |    |    |-- photo_320: string (nullable = true)
#  |    |    |    |-- photo_640: string (nullable = true)
#  |    |    |    |-- photo_800: string (nullable = true)
#  |    |    |    |-- platform: string (nullable = true)
#  |    |    |    |-- repeat: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- track_code: string (nullable = true)
#  |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |-- views: long (nullable = true)
#  |    |    |    |-- width: long (nullable = true)
#  |-- comments: struct (nullable = true)
#  |    |-- can_post: long (nullable = true)
#  |    |-- count: long (nullable = true)
#  |    |-- groups_can_post: boolean (nullable = true)
#  |-- copy_history: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- attachments: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- album: struct (nullable = true)
#  |    |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- updated: long (nullable = true)
#  |    |    |    |    |-- audio: struct (nullable = true)
#  |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |    |    |-- content_restricted: long (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |    |    |-- genre_id: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- is_hq: boolean (nullable = true)
#  |    |    |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- doc: struct (nullable = true)
#  |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- ext: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- preview: struct (nullable = true)
#  |    |    |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- video: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- file_size: long (nullable = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- type: long (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- link: struct (nullable = true)
#  |    |    |    |    |    |-- button: struct (nullable = true)
#  |    |    |    |    |    |    |-- action: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- button_action: string (nullable = true)
#  |    |    |    |    |    |-- button_text: string (nullable = true)
#  |    |    |    |    |    |-- caption: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |    |-- target: string (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- page: struct (nullable = true)
#  |    |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |    |-- edited: long (nullable = true)
#  |    |    |    |    |    |-- group_id: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- parent2: string (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- view_url: string (nullable = true)
#  |    |    |    |    |    |-- views: long (nullable = true)
#  |    |    |    |    |    |-- who_can_edit: long (nullable = true)
#  |    |    |    |    |    |-- who_can_view: long (nullable = true)
#  |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |    |-- long: double (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |-- podcast: struct (nullable = true)
#  |    |    |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- podcast_info: struct (nullable = true)
#  |    |    |    |    |    |    |-- cover: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |-- plays: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- poll: struct (nullable = true)
#  |    |    |    |    |    |-- anonymous: long (nullable = true)
#  |    |    |    |    |    |-- answer_id: long (nullable = true)
#  |    |    |    |    |    |-- answers: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |-- rate: double (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |    |-- votes: long (nullable = true)
#  |    |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- question: string (nullable = true)
#  |    |    |    |    |    |-- votes: long (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- video: struct (nullable = true)
#  |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |-- can_add: long (nullable = true)
#  |    |    |    |    |    |-- comments: long (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |    |    |-- first_frame_1024: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_1280: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_130: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_160: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_320: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_4096: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_720: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_800: string (nullable = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- local_views: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- photo_1280: string (nullable = true)
#  |    |    |    |    |    |-- photo_130: string (nullable = true)
#  |    |    |    |    |    |-- photo_320: string (nullable = true)
#  |    |    |    |    |    |-- photo_640: string (nullable = true)
#  |    |    |    |    |    |-- photo_800: string (nullable = true)
#  |    |    |    |    |    |-- platform: string (nullable = true)
#  |    |    |    |    |    |-- repeat: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- track_code: string (nullable = true)
#  |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |    |-- views: long (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |-- date: long (nullable = true)
#  |    |    |-- from_id: long (nullable = true)
#  |    |    |-- geo: struct (nullable = true)
#  |    |    |    |-- coordinates: string (nullable = true)
#  |    |    |    |-- place: struct (nullable = true)
#  |    |    |    |    |-- city: string (nullable = true)
#  |    |    |    |    |-- country: string (nullable = true)
#  |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |-- icon: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- latitude: double (nullable = true)
#  |    |    |    |    |-- longitude: double (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- showmap: long (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- owner_id: long (nullable = true)
#  |    |    |-- post_source: struct (nullable = true)
#  |    |    |    |-- data: string (nullable = true)
#  |    |    |    |-- platform: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- post_type: string (nullable = true)
#  |    |    |-- signer_id: long (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- copyright: struct (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- link: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- date: long (nullable = true)
#  |-- from_id: long (nullable = true)
#  |-- geo: struct (nullable = true)
#  |    |-- coordinates: string (nullable = true)
#  |    |-- place: struct (nullable = true)
#  |    |    |-- city: string (nullable = true)
#  |    |    |-- country: string (nullable = true)
#  |    |    |-- created: long (nullable = true)
#  |    |    |-- icon: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- latitude: double (nullable = true)
#  |    |    |-- longitude: double (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |-- showmap: long (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- key: string (nullable = true)
#  |-- likes: struct (nullable = true)
#  |    |-- can_like: long (nullable = true)
#  |    |-- can_publish: long (nullable = true)
#  |    |-- count: long (nullable = true)
#  |    |-- user_likes: long (nullable = true)
#  |-- marked_as_ads: long (nullable = true)
#  |-- owner_id: long (nullable = true)
#  |-- post_source: struct (nullable = true)
#  |    |-- data: string (nullable = true)
#  |    |-- platform: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- post_type: string (nullable = true)
#  |-- reposts: struct (nullable = true)
#  |    |-- count: long (nullable = true)
#  |    |-- user_reposted: long (nullable = true)
#  |-- signer_id: long (nullable = true)
#  |-- text: string (nullable = true)
#  |-- unavailable: string (nullable = true)
#  |-- views: struct (nullable = true)
#  |    |-- count: long (nullable = true)

# %%
emoji_df = posts_df.where("text <> ''").select('id', get_emoji_udf(col("text")).name('emoji'))\
        .where(F.size('emoji') > 0)\
        .withColumn('emoji', F.explode("emoji"))\
        .groupBy('emoji')\
        .agg(F.count('id').name('all_count'), F.countDistinct('id').name('posts_count'))\
        .withColumn('avg_per_post', col('all_count') / col('posts_count'))\
        .withColumn('difference', col('all_count') - col('posts_count'))\
        .orderBy(F.desc('all_count'))


emoji_df.limit(5)\
        .toPandas()
# Out:
#   emoji  all_count  posts_count  avg_per_post  difference
# 0     🔥         76           61      1.245902          15
# 1     ⚡         68           45      1.511111          23
# 2     📍         63           39      1.615385          24
# 3     🚀         50           47      1.063830           3
# 4     ❤         47           47      1.000000           0

# %% [markdown]
# Print top 10 most popular emoticons

# %%
emoji_df.limit(10)\
        .toPandas()
# Out:
#   emoji  all_count  posts_count  avg_per_post  difference
# 0     🔥         76           61      1.245902          15
# 1     ⚡         68           45      1.511111          23
# 2     📍         63           39      1.615385          24
# 3     🚀         50           47      1.063830           3
# 4     ❤         47           47      1.000000           0
# 5     ❗         45           20      2.250000          25
# 6     🔵         40           17      2.352941          23
# 7     ⬇         40           16      2.500000          24
# 8     ✔         40            9      4.444444          31
# 9     💙         38           38      1.000000           0

# %% [markdown]
# Print top 5 emoticons which have the greatest difference between their overall count and frequency

# %%
emoji_df.orderBy(F.desc('difference'))\
        .limit(5)\
        .toPandas()
# Out:
#   emoji  all_count  posts_count  avg_per_post  difference
# 0     ✔         40            9      4.444444          31
# 1     ❗         45           20      2.250000          25
# 2     ⬇         40           16      2.500000          24
# 3     📍         63           39      1.615385          24
# 4     🔵         40           17      2.352941          23

# %% [markdown]
# Print top 5 emoticons with average count per post

# %%
emoji_df.orderBy(F.desc('avg_per_post'))\
        .limit(5)\
        .toPandas()
# Out:
#   emoji  all_count  posts_count  avg_per_post  difference
# 0     ✔         40            9      4.444444          31
# 1     🔹         30            7      4.285714          23
# 2     ▪         21            5      4.200000          16
# 3     ✒          7            2      3.500000           5
# 4     📷          3            1      3.000000           2

# %% [markdown]
# ## Task 5
# Probable “fans”. Find for each user the top 10 other users whose posts this user likes.

# %%
followers_posts_likes_df.printSchema()
# Out:
# root
#  |-- itemType: string (nullable = true)
#  |-- ownerId: integer (nullable = true)
#  |-- itemId: integer (nullable = true)
#  |-- likerId: integer (nullable = true)

# %%
from pyspark.sql.window import Window

# %%
followers_posts_likes_df.select(col('ownerId').name('user_id'), 'itemId', 'likerId')\
                        .groupBy('likerId', 'user_id')\
                        .agg(F.count('itemId').name("likes_count"))\
                        .withColumn("top", F.row_number().over(Window.partitionBy("likerId").orderBy(F.desc("likes_count"))))\
                        .where('top <= 10')\
                        .orderBy('likerId', F.desc("likes_count"))\
                        .show()
# Out:
# +-------+--------+-----------+---+
# |likerId| user_id|likes_count|top|
# +-------+--------+-----------+---+
# |      9|  654356|          4|  1|
# |     14| 1986125|          2|  1|
# |     14|    3420|          1|  2|
# |     14|   35524|          1|  3|
# |     14| 3680017|          1|  4|
# |     15| 1227412|          2|  2|
# |     15|  473831|          2|  1|
# |     17| 1986125|         10|  1|
# |     17|    3420|          3|  2|
# |     17|   88060|          2|  3|
# |     34|   50601|          1|  2|
# |     34| 1986125|          1|  1|
# |     63|   73115|          1|  1|
# |     99| 1550591|          1|  1|
# |    122|   55983|          1|  1|
# |    143|     637|          3|  1|
# |    146|19515730|          3|  1|
# |    146|  106610|          2|  2|
# |    149| 1986125|          1|  1|
# |    154| 1601367|          1|  1|
# +-------+--------+-----------+---+
# only showing top 20 rows

# %% [markdown]
# ## Task 6
# Probable friends. If two users like each other posts they may be friends. Find pairs of users where both users are top likers of each other.

# %%
posts_likes_df.printSchema()
# Out:
# root
#  |-- itemType: string (nullable = true)
#  |-- ownerId: integer (nullable = true)
#  |-- itemId: integer (nullable = true)
#  |-- likerId: integer (nullable = true)

# %%
user_df_1 = followers_posts_likes_df\
    .select(col("ownerId").name("user_1"), col("likerId").alias("user_2"), col("itemId"))

user_df_2 = followers_posts_likes_df\
    .select(col("ownerId").name("user_2"), col("likerId").alias("user_1"))

user_df_3 = user_df_1.join(user_df_2, ["user_1", "user_2"]).where("user_1 != user_2")\
    .groupBy("user_1", "user_2").agg(F.count("itemId").alias("cnt_posts"))\
    .orderBy(F.desc("cnt_posts"))

# %%
user_df_3.withColumn('first_user', F.least('user_1', 'user_2'))\
         .withColumn('second_user', F.greatest('user_1', 'user_2'))\
         .drop('user_1', 'user_2')\
         .dropDuplicates()\
         .orderBy(F.desc('cnt_posts'))\
         .show()
# Out:
# +---------+----------+-----------+
# |cnt_posts|first_user|second_user|
# +---------+----------+-----------+
# |    16100|  13675440|  183535934|
# |     1972|   1475301|    5633955|
# |     1612| 207134315|  208946862|
# |     1456| 145105762|  267301242|
# |      880|    108408|    7697818|
# |      810|    135451|   18737802|
# |      720| 209077977|  272076217|
# |      684| 155963006|  162366815|
# |      608|   2547211|    4448812|
# |      598|  19261491|  229861638|
# |      572|  53368685|  322831238|
# |      544|  52612744|   53720099|
# |      506|  66022003|   95356919|
# |      390|  83892412|  115252127|
# |      376|  47122493|   63363182|
# |      330|  27102997|   74634237|
# |      330|  44770563|  103229751|
# |      312| 101767883|  188548515|
# |      300|   1475301|    4068532|
# |      299|  34892097|   59949877|
# +---------+----------+-----------+
# only showing top 20 rows
